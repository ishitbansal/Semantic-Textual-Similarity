# %% [markdown]
# <h1> Doc2Vec embeddings </h1>
# <p>Doc2Vec model is trained to generate representative embeddings of sentences and with these embeddings following approaches are applied to generate STS scores:</p>
# <li>Normalized cosine similarity score </li>
# <li>BiLSTM Regression neural network model</li>
# <li>BiGRU Regression neural network model</li>

# %%
import pandas as pd
import numpy as np
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from scipy import spatial
from scipy.stats import pearsonr
import torch
import torch.nn as nn
import torch.utils.data as data
from sklearn.linear_model import LinearRegression
import logging
import warnings
import sys

logging.disable(logging.WARNING)
warnings.filterwarnings('ignore')
np.set_printoptions(threshold=sys.maxsize)

# %%
def pearson_corr(y_true, y_pred):
    corr, _ = pearsonr(y_true, y_pred)
    return corr

# %% [markdown]
# ## Mono-Lingual Semantic Similarity

# %%
train_data = pd.read_csv('./data/train.csv')
val_data = pd.read_csv('./data/validation.csv')
test_data = pd.read_csv('./data/test.csv')

train_data['sentence1'] = train_data['sentence1'].apply(eval)
train_data['sentence2'] = train_data['sentence2'].apply(eval)
val_data['sentence1'] = val_data['sentence1'].apply(eval)
val_data['sentence2'] = val_data['sentence2'].apply(eval)
test_data['sentence1'] = test_data['sentence1'].apply(eval)
test_data['sentence2'] = test_data['sentence2'].apply(eval)

# %%
total_sents_unk = list(train_data['sentence1'])
total_sents_unk.extend(list(train_data['sentence2']))
total_sents_unk
# Out:
# [['plane', 'take'],
#  ['man', 'play', 'larg', 'flute'],
#  ['man', 'spread', 'shrede', 'chees', 'pizza'],
#  ['three', 'men', 'play', 'chess'],
#  ['man', 'play', 'cello'],
#  ['men', 'fight'],
#  ['man', 'smoke'],
#  ['man', 'play', 'piano'],
#  ['man', 'play', 'guitar', 'sing'],
#  ['person', 'throw', 'cat', 'ceil'],
#  ['man', 'hit', 'man', 'stick'],
#  ['woman', 'pick', 'hold', 'babi', 'kangaroo'],
#  ['man', 'play', 'flute'],
#  ['person', 'fold', 'piec', 'paper'],
#  ['man', 'run', 'road'],
#  ['dog', 'tri', 'get', 'bacon', 'back'],
#  ['polar', 'bear', 'slide', 'snow'],
#  ['woman', 'write'],
#  ['cat', 'rub', 'babi', 'face'],
#  ['man', 'ride', 'hors'],
#  ['man', 'pour', 'oil', 'pot'],
#  ['man', 'play', 'guitar'],
#  ['panda', 'slide', 'slide'],
#  ['woman', 'eat', 'someth'],
#  ['woman', 'peel', 'potato'],
#  ['boy', 'fell', 'bike'],
#  ['woman', 'play', 'flute'],
#  ['rabbit', 'run', 'eagl'],
#  ['woman', 'fri', 'bread', 'pork', 'chop'],
#  ['girl', 'fli', 'kite'],
#  ['man', 'ride', 'mechan', 'bull'],
#  ['man', 'play', 'guitar'],
#  ['woman', 'danc', 'sing', 'woman'],
#  ['man', 'slice', 'bun'],
#  ['man', 'pour', 'oil', 'pan'],
#  ['lion', 'play', 'peopl'],
#  ['dog', 'ride', 'skateboard'],
#  ['someon', 'carv', 'statu'],
#  ['woman', 'slice', 'onion'],
#  ['woman', 'peel', 'shrimp'],
#  ['woman', 'fri', 'fish'],
#  ['woman', 'play', 'electr', 'guitar'],
#  ['babi', 'tiger', 'play', 'ball'],
#  ['person', 'slice', 'tomato'],
#  ['person', 'cut', 'onion'],
#  ['man', 'play', 'piano'],
#  ['woman', 'play', 'flute'],
#  ['man', 'cut', 'potato'],
#  ['kid', 'play', 'guitar'],
#  ['boy', 'play', 'guitar'],
#  ['man', 'play', 'guitar'],
#  ['littl', 'boy', 'play', 'keyboard'],
#  ['man', 'play', 'guitar'],
#  ['dog', 'lick', 'babi'],
#  ['woman', 'slice', 'onion'],
#  ['man', 'play', 'guitar'],
#  ['woman', 'slice', 'pepper'],
#  ['man', 'play', 'drum'],
#  ['woman', 'ride', 'hors'],
#  ['man', 'eat', 'banana', 'tree'],
#  ['cat', 'play', 'key', 'board'],
#  ['man', 'chop', 'tree', 'axe'],
#  ['kid', 'play', 'toy', 'phone'],
#  ['man', 'ride', 'motorcycl'],
#  ['man', 'ride', 'motorcycl'],
#  ['squirrel', 'spin', 'around', 'circl'],
#  ['man', 'woman', 'kiss'],
#  ['man', 'get', 'car'],
#  ['man', 'danc'],
#  ['man', 'play', 'guitar', 'sing'],
#  ['person', 'cut', 'mushroom'],
#  ['tiger', 'cub', 'make', 'sound'],
#  ['person', 'slice', 'onion'],
#  ['man', 'play', 'piano'],
#  ['woman', 'peel', 'potato'],
#  ['pankda', 'eat', 'bamboo'],
#  ['person', 'peel', 'onion'],
#  ['monkey', 'push', 'anoth', 'monkey'],
#  ['squirrel', 'run', 'around', 'circl'],
#  ['man', 'tie', 'shoe'],
#  ['boy', 'sing', 'play', 'piano'],
#  ['dog', 'eat', 'water', 'melon'],
#  ['woman', 'chop', 'broccoli'],
#  ['man', 'peel', 'potato'],
#  ['woman', 'play', 'guitar'],
#  ['woman', 'slice', 'tomato'],
#  ['man', 'swim', 'underwat'],
#  ['man', 'woman', 'talk'],
#  ['small', 'dog', 'chase', 'yoga', 'ball'],
#  ['men', 'play', 'cricket'],
#  ['man', 'ride', 'motorcycl'],
#  ['man', 'play', 'guitar'],
#  ['man', 'talk', 'telephon'],
#  ['man', 'fish'],
#  ['man', 'levit'],
#  ['two', 'boy', 'drive'],
#  ['man', 'ride', 'hors'],
#  ['man', 'ride', 'bicycl'],
#  ['man', 'slice', 'potato'],
#  ['woman', 'peel', 'potato'],
#  ['man', 'play', 'guitar'],
#  ['woman', 'slice', 'leek'],
#  ['man', 'cut', 'paper', 'plate'],
#  ['man', 'play', 'guitar'],
#  ['man', 'play', 'piano'],
#  ['woman', 'slice', 'meat'],
#  ['man', 'play', 'keyboard'],
#  ['ladi', 'chop', 'green', 'onion'],
#  ['someon', 'sitr', 'noodl', 'water'],
#  ['lionel', 'richi', 'danc', 'ceil'],
#  ['man', 'play', 'piano'],
#  ['woman', 'play', 'flute'],
#  ['boy', 'check', 'calend'],
#  ['woman', 'cut', 'onion'],
#  ['man', 'play', 'guitar'],
#  ['woman', 'use', 'sew', 'machin'],
#  ['woman', 'flip', 'pancak'],
#  ['man', 'run', 'road'],
#  ['man', 'ride', 'hors'],
#  ['man', 'ride', 'bike'],
#  ['woman', 'danc'],
#  ['man', 'play', 'piano'],
#  ['man', 'play', 'flute'],
#  ['man', 'spin'],
#  ['monkey', 'swing', 'limb', 'limb'],
#  ['peopl', 'got', 'train'],
#  ['dog', 'jump', 'trampolin'],
#  ['boy', 'play', 'instrument'],
#  ['woman', 'play', 'guitar'],
#  ['woman', 'pick'],
#  ['man', 'climb', 'rope'],
#  ['man', 'lift', 'car'],
#  ['man', 'woman', 'drive', 'street', 'jeep'],
#  ['shirtless', 'man', 'sat', 'chair'],
#  ['two', 'woman', 'wrestl'],
#  ['puppi', 'play', 'blue', 'tenni', 'ball'],
#  ['kangroo', 'eat', 'someth'],
#  ['cat', 'play', 'piano'],
#  ['man', 'cut', 'carpet', 'knife'],
#  ['woman', 'ride', 'motor', 'scooter', 'road'],
#  ['someon', 'slice', 'veget'],
#  ['woman', 'danc'],
#  ['dog', 'lick', 'babi', 'drool'],
#  ['man', 'row', 'boat'],
#  ['man', 'cut', 'potato'],
#  ['woman', 'chop', 'garlic'],
#  ['anim', 'run', 'circl'],
#  ['man', 'walk', 'slowli', 'across', 'rope', 'bridg'],
#  ['man', 'play', 'guitar'],
#  ['man', 'play', 'flute'],
#  ['woman', 'crack', 'two', 'egg', 'glass', 'bowl'],
#  ['man', 'cut', 'fish'],
#  ['two', 'men', 'pack', 'suitcas', 'trunk', 'car'],
#  ['man', 'pour', 'oil', 'tomato'],
#  ['man', 'slice', 'someth'],
#  ['man', 'paddl', 'cano'],
#  ['man', 'woman', 'walk', 'togeth', 'wood'],
#  ['woman', 'pick', 'kangaroo'],
#  ['fish', 'swim'],
#  ['two', 'woman', 'mix', 'someth', 'food', 'processor'],
#  ['person', 'surf', 'larg', 'wave'],
#  ['man', 'play', 'guitar'],
#  ['man', 'play', 'flute', 'band'],
#  ['man', 'spread', 'butter', 'loaf', 'bread'],
#  ['person', 'boil', 'noodl'],
#  ['group', 'peopl', 'danc', 'hill'],
#  ['man', 'danc', 'outsid'],
#  ['woman', 'feed', 'man'],
#  ['man', 'put', 'pan', 'oven'],
#  ['woman', 'sit', 'desk'],
#  ['medic', 'transport', 'patient', 'stretcher'],
#  ['woman', 'play', 'flute', 'stage'],
#  ['two', 'babi', 'panda', 'play'],
#  ['babi', 'laugh'],
#  ['man', 'play', 'guitar'],
#  ['man', 'fold', 'paper'],
#  ['three', 'woman', 'danc'],
#  ['cat', 'play'],
#  ['person', 'write'],
#  ['man', 'run'],
#  ['woman', 'roll', 'dough'],
#  ['woman', 'ad', 'spice', 'meat'],
#  ['woman', 'ad', 'oil', 'fish'],
#  ['young', 'boy', 'hold', 'guitar'],
#  ['cheetah', 'run'],
#  ['man', 'eat', 'pizza'],
#  ['orangutan', 'ride', 'bu'],
#  ['man', 'woman', 'talk', 'diner'],
#  ['man', 'play', 'guitar'],
#  ['girl', 'sing', 'play', 'guitar'],
#  ['girl', 'commun', 'sign', 'languag'],
#  ['woman', 'weight', 'exercis'],
#  ['man', 'get', 'insid', 'car'],
#  ['big', 'green', 'ball', 'knock', 'potato'],
#  ['cat', 'play', 'keyboard'],
#  ['two', 'dog', 'swim', 'pool'],
#  ['man', 'use', 'chopper', 'chop', 'onion'],
#  ['woman', 'slice', 'tofu'],
#  ['herd', 'deer', 'cross', 'street'],
#  ['person', 'ride', 'hors'],
#  ['someon', 'feed', 'anim'],
#  ['someon', 'slice', 'tortila'],
#  ['someon', 'mix', 'ingredi'],
#  ['rooster', 'peck', 'dead', 'mous'],
#  ['woman', 'hold', 'kangaroo'],
#  ['man', 'play', 'frog'],
#  ['two', 'men', 'talk'],
#  ['man', 'spread', 'butter', 'big', 'piec', 'bread'],
#  ['man', 'run', 'across', 'high', 'wire'],
#  ['man', 'mow', 'lawn'],
#  ['man', 'open', 'door'],
#  ['man', 'slice', 'potato', 'piec'],
#  ['woman', 'cut', 'cook', 'octopu'],
#  ['man', 'punch', 'board'],
#  ['man', 'danc'],
#  ['someon', 'play', 'piano'],
#  ['two', 'fox', 'eat', 'plate', 'brick', 'patio'],
#  ['boy', 'play', 'keyboard'],
#  ['person', 'play', 'keyboard'],
#  ['man', 'shoot', 'gun'],
#  ['someon', 'slice', 'onion'],
#  ['man', 'swim'],
#  ['man', 'play', 'guitar'],
#  ['woman', 'slice', 'pumpkin'],
#  ['woman', 'danc'],
#  ['woman', 'crack', 'egg', 'bowl'],
#  ['car', 'move', 'road'],
#  ['someon', 'greas', 'pan'],
#  ['man', 'play', 'guitar'],
#  ['woman', 'drink', 'vodka'],
#  ['woman', 'cut', 'meat', 'piec'],
#  ['man', 'rins', 'steak'],
#  ['man', 'sell', 'item'],
#  ['man', 'jump', 'wall'],
#  ['runner', 'race', 'around', 'track'],
#  ['man', 'kick', 'soccer', 'ball'],
#  ['woman', 'fri', 'someth'],
#  ['cat', 'lick', 'sucker'],
#  ['woman', 'danc', 'fire'],
#  ['man', 'slice', 'fish', 'open'],
#  ['butter', 'melt', 'pan'],
#  ['three', 'boy', 'danc'],
#  ['woman', 'play', 'game', 'man'],
#  ['man', 'drive', 'white', 'car'],
#  ['man', 'drove', 'car'],
#  ['car', 'back', 'space'],
#  ['man', 'put', 'chees', 'pizza'],
#  ['boy', 'play', 'piano'],
#  ['man', 'play', 'guitar'],
#  ['man', 'ride', 'hors'],
#  ['man', 'walk', 'rope'],
#  ['girl', 'play', 'flute'],
#  ['peopl', 'step', 'train'],
#  ['woman', 'sew', 'machin'],
#  ['dog', 'look', 'swim', 'pool'],
#  ['man', 'butter', 'piec', 'bread'],
#  ['man', 'cut', 'tomato', 'piec'],
#  ['three', 'teenag', 'girl', 'danc', 'room'],
#  ['lion', 'walk'],
#  ['man', 'shoot', 'car'],
#  ['black', 'hors', 'run', 'around'],
#  ['woman', 'devein', 'shrimp'],
#  ['man', 'ride', 'hors'],
#  ['man', 'walk', 'path'],
#  ['man', 'slice', 'potato'],
#  ['dog', 'bark', 'ball'],
#  ['kid', 'run', 'away', 'fish', 'swing', 'around', 'fish', 'pole'],
#  ['man', 'walk', 'along', 'path', 'wilder'],
#  ['elderli', 'man', 'speak', 'podium'],
#  ['man', 'ride', 'hors', 'slow', 'motion'],
#  ['person', 'cut', 'burrata', 'chees'],
#  ['man', 'shoot', 'automat', 'rifl'],
#  ['man', 'crush', 'garlic', 'back', 'knife'],
#  ['woman', 'file', 'fingernail', 'emeri', 'board'],
#  ['man', 'ride', 'skateboard'],
#  ['woman', 'take', 'shower'],
#  ['man', 'danc'],
#  ['man', 'row', 'boat'],
#  ['man', 'swing', 'rope', 'attach', 'ceil'],
#  ['woman', 'ride', 'hors', 'beach'],
#  ['man', 'hold', 'small', 'anim', 'one', 'hand'],
#  ['person', 'fold', 'squar', 'paper', 'piec'],
#  ['person', 'fri', 'meat', 'pan'],
#  ['chimpanze', 'hurt', 'woman'],
#  ['woman', 'peel', 'shrimp'],
#  ['two', 'zebra', 'play'],
#  ['woman', 'slice', 'butter'],
#  ['men', 'play', 'guitar'],
#  ['eleph', 'spray', 'water'],
#  ['dog', 'sat', 'counter', 'store'],
#  ['someon', 'drill', 'hole', 'strip', 'wood', 'power', 'drill'],
#  ['woman', 'slice', 'veget'],
#  ['badger', 'burrow', 'hole'],
#  ['woman', 'water', 'ski', 'lake'],
#  ['girl', 'play', 'violin'],
#  ['helicopt', 'land', 'helipad'],
#  ['woman', 'cut', 'chicken'],
#  ['woman', 'cut', 'cucumb'],
#  ['woman', 'ride', 'eleph', 'front', 'ador', 'crowd'],
#  ['puppi', 'slide', 'backward', 'along', 'floor'],
#  ['woman', 'split', 'garlic', 'clove'],
#  ['dog', 'look', 'swim', 'pool'],
#  ['woman', 'mix', 'beauti', 'treatment', 'glass'],
#  ['man', 'draw', 'pictur'],
#  ['woman', 'pick', 'tomato'],
#  ['man', 'look', 'comput', 'monitor'],
#  ['boy', 'ride', 'tricycl'],
#  ['two', 'men', 'compet', 'tire', 'roll', 'race'],
#  ['person', 'cut', 'meat'],
#  ['man', 'play', 'violin'],
#  ['babi', 'crawl', 'doorway'],
#  ['man', 'play', 'keyboard'],
#  ['man', 'smell', 'two', 'pizza'],
#  ['monkey', 'pull', 'tail', 'dog'],
#  ['dog', 'lie', 'back', 'wooden', 'floor'],
#  ['woman', 'fri', 'someth', 'pan'],
#  ['man', 'put', 'season', 'bowl', 'water'],
#  ['elderli', 'woman', 'pour', 'oil', 'fri', 'pan'],
#  ['woman', 'chop', 'onion'],
#  ['woman', 'pick', 'kangaroo'],
#  ['dog', 'bite'],
#  ['woman', 'debon', 'fish'],
#  ['man', 'mow', 'grass'],
#  ['cat', 'watch', 'tv'],
#  ['boy', 'stuck', 'door', 'doghous'],
#  ['peopl', 'flip', 'swim', 'pool'],
#  ['woman', 'swim', 'underwat'],
#  ['man', 'play', 'guitar'],
#  ['airplan', 'fli', 'air'],
#  ['bear', 'run', 'two', 'dog'],
#  ['woman', 'rest', 'float', 'raft'],
#  ['man', 'die', 'oper', 'room'],
#  ['man', 'hold', 'leaf'],
#  ['person', 'ride', 'hors'],
#  ['woman', 'slice', 'octopu'],
#  ['man', 'break', 'water', 'jug'],
#  ['man', 'play', 'guitar'],
#  ['girl', 'eat', 'cupcak'],
#  ['littl', 'girl', 'play', 'grass', 'dog', 'ball'],
#  ['peopl', 'ride', 'paddl', 'raft'],
#  ['ladi', 'cut', 'potato'],
#  ['missil', 'explod'],
#  ['dog', 'play', 'snow'],
#  ['woman', 'danc', 'woman'],
#  ['boy', 'push', 'van'],
#  ['boy', 'make', 'danc', 'step'],
#  ['woman', 'open', 'soda', 'drink'],
#  ['man', 'assembl', 'speaker', 'part'],
#  ['dog', 'walk', 'along', 'edg', 'pool'],
#  ['butter', 'put', 'bowl'],
#  ['raccoon', 'eat'],
#  ['someon', 'fell', 'hors'],
#  ['woman', 'peel', 'appl'],
#  ['man', 'take', 'math', 'class'],
#  ['anim', 'play', 'water'],
#  ['man', 'ride', 'hors', 'jump', 'obstacl'],
#  ['person', 'pencil', 'trick', 'hand'],
#  ['person', 'lit', 'camera', 'fire'],
#  ['man', 'slice', 'tape', 'box'],
#  ['man', 'fish', 'river'],
#  ['man', 'ride', 'bike'],
#  ['man', 'pushup'],
#  ['man', 'play', 'guitar'],
#  ['littl', 'boy', 'sing', 'play', 'guitar'],
#  ['woman', 'powder', 'face'],
#  ['woman', 'peel', 'potato'],
#  ['woman', 'fire', 'rifl'],
#  ['woman', 'put', 'garland', 'man', 'shoulder'],
#  ['old', 'woman', 'shake', 'hand', 'man'],
#  ['woman', 'waterski'],
#  ['tree', 'bend', 'storm'],
#  ['man', 'woman', 'ride', 'car'],
#  ['man', 'move', 'tree', 'limb'],
#  ['man', 'play', 'piano'],
#  ['person', 'pour', 'oil', 'skillet'],
#  ['anim', 'eat'],
#  ['woman', 'walk', 'dog'],
#  ['group', 'peopl', 'sing'],
#  ['cat', 'drink', 'milk'],
#  ['girl', 'make', 'eyelid'],
#  ['two', 'men', 'fight'],
#  ['militari', 'offic', 'bark', 'recruit'],
#  ['man', 'put', 'chicken', 'contain'],
#  ['man', 'tie', 'stenograph', 'machin'],
#  ['woman', 'ad', 'pasta', 'pot', 'water'],
#  ['woman', 'lie', 'blanket', 'rock', 'read', 'book'],
#  ['two', 'puppi', 'play'],
#  ['man', 'run', 'field'],
#  ['man', 'hug', 'someon'],
#  ['someon', 'pour', 'ingredi', 'pot'],
#  ['coupl', 'walk'],
#  ['person', 'play', 'guitar'],
#  ['person', 'ad', 'food', 'pan'],
#  ['group', 'penguin', 'walk'],
#  ['man', 'play', 'guitar'],
#  ['dog', 'jump', 'trampolin'],
#  ['man', 'shake', 'contain', 'kitchen', 'sink'],
#  ['man', 'walk', 'hors'],
#  ['paper', 'cut', 'scissor'],
#  ['person', 'peel', 'shrimp'],
#  ['man', 'play', 'guitar'],
#  ['man', 'make', 'bed', 'hotel'],
#  ['dog', 'pull', 'dog', 'tail', 'leg'],
#  ['woman', 'beat', 'two', 'egg', 'bowl'],
#  ['man', 'jump', 'rope', 'outsid'],
#  ['person', 'slice', 'onion'],
#  ['woman', 'hold', 'kangaroo'],
#  ['soccer', 'player', 'kick', 'soccer', 'ball', 'goal'],
#  ['woman', 'cook', 'someth'],
#  ['woman', 'swim', 'beach'],
#  ['man', 'carri', 'anoth', 'man'],
#  ['woman', 'put', 'past', 'dish'],
#  ['man', 'hold', 'talk', 'gray', 'tube', 'tshirt'],
#  ['someon', 'pour', 'oliv', 'oil', 'bowl', 'tomato', 'wedg'],
#  ['man', 'play', 'guitar'],
#  ['someon', 'boil', 'okra', 'pot'],
#  ['person', 'peel', 'potato'],
#  ['cat', 'jump', 'box'],
#  ['woman', 'season', 'oil'],
#  ['cat', 'slide', 'upsid', 'couch'],
#  ['woman', 'danc', 'man', 'play', 'keyboard'],
#  ['chef', 'clean', 'bowl', 'soup'],
#  ['explos', 'boom', 'desert'],
#  ['woman', 'slice', 'lemon'],
#  ['overweight', 'man', 'skip', 'rope'],
#  ['ladi', 'crack', 'two', 'raw', 'egg'],
#  ['man', 'sharpen', 'pencil', 'use', 'knife'],
#  ['plastic', 'toy', 'float', 'water'],
#  ['turtl', 'follow', 'fish'],
#  ['woman', 'pencil', 'eye', 'shadow'],
#  ['man', 'tie', 'shoe'],
#  ['woman', 'slice', 'meat', 'knife'],
#  ['dog', 'run', 'ground'],
#  ['man', 'pet', 'tie', 'dog'],
#  ['woman', 'walk', 'open', 'ground', 'pet', 'dog', 'dog', 'follow'],
#  ['woman', 'minc', 'garlic'],
#  ['two', 'team', 'play', 'soccer'],
#  ['rat', 'like', 'creatur', 'smell', 'around'],
#  ['two', 'sumo', 'ringer', 'fight'],
#  ['man', 'lay', 'ground', 'aim', 'rifl'],
#  ['coupl', 'run', 'toward', 'ocean'],
#  ['woman', 'chop', 'hard', 'egg'],
#  ['two', 'robot', 'share', 'kiss'],
#  ['cat', 'tri', 'touch', 'dog'],
#  ['rhino', 'graze', 'grass'],
#  ['man', 'drove', 'littl', 'red', 'car', 'around', 'traffic'],
#  ['man', 'cut', 'bread'],
#  ['cat', 'rapidli', 'swat', 'kid', 'head'],
#  ['cat', 'play', 'box'],
#  ['coupl', 'danc', 'church'],
#  ['man', 'pat', 'allig', 'mouth'],
#  ['person', 'check', 'rice', 'pud'],
#  ['woman', 'stir', 'two', 'egg', 'glass', 'bowl'],
#  ['man', 'play', 'drum'],
#  ['man', 'slice', 'pepper'],
#  ['woman', 'speak', 'sign', 'languag'],
#  ['boy', 'crawl', 'dog', 'hous'],
#  ['girl', 'flew', 'kite', 'ran', 'hill'],
#  ['woman', 'place', 'food', 'pot', 'hot', 'water'],
#  ['small', 'monkey', 'walk', 'water'],
#  ['man', 'ride', 'bike'],
#  ['young', 'man', 'sing', 'play', 'piano'],
#  ['boy', 'take', 'sunglass'],
#  ['girl', 'play', 'piano'],
#  ['ladi', 'slice', 'tomato'],
#  ['someon', 'hold', 'hedgehog'],
#  ['woman', 'peel', 'potato'],
#  ['cat', 'drink', 'water'],
#  ['person', 'put', 'salt', 'pepper', 'piec', 'pork'],
#  ['man', 'sat', 'chair', 'stare'],
#  ['woman', 'dice', 'potato'],
#  ['babi', 'crawl', 'happili'],
#  ['person', 'fri', 'meat', 'pan'],
#  ['man', 'look', 'window'],
#  ['man', 'seat', 'play', 'guitar'],
#  ['woman', 'slice', 'onion', 'knife'],
#  ['rider', 'run', 'jump', 'hors'],
#  ['boy', 'play', 'keyboard'],
#  ['two', 'men', 'fight'],
#  ['man', 'play', 'wooden', 'flute', 'sever', 'men', 'play', 'bongo', 'drum'],
#  ['person', 'pet', 'monkey'],
#  ['two', 'cartoon', 'rabbit', 'kiss'],
#  ['hedgehog', 'chew', 'towel'],
#  ['cat', 'lick'],
#  ['small', 'guinea', 'pig', 'gnaw', 'eat', 'piec', 'carrot', 'floor'],
#  ['four', 'boy', 'stand', 'front', 'burn', 'car'],
#  ['man', 'smoke'],
#  ['woman', 'ad', 'sauc', 'food'],
#  ['three', 'child', 'eat', 'food'],
#  ['submarin', 'go', 'water'],
#  ['man', 'run', 'street'],
#  ['person', 'slice', 'onion'],
#  ['badger', 'dig', 'dirt'],
#  ['woman', 'slice', 'big', 'pepper'],
#  ['man', 'ride', 'bicycl'],
#  ['man', 'woman', 'kiss'],
#  ['woman', 'slice', 'onion'],
#  ['small', 'boy', 'play', 'dog'],
#  ['man', 'draw'],
#  ['man', 'cut', 'potato'],
#  ['boy', 'play', 'guitar'],
#  ['woman', 'cut', 'onion'],
#  ['toy', 'train', 'strike', 'toy', 'car'],
#  ['man', 'play', 'guitar'],
#  ['cat', 'open', 'drawer', 'climb', 'insid'],
#  ['woman', 'fri', 'food'],
#  ['man', 'dice', 'onion'],
#  ['girl', 'play', 'guitar'],
#  ['girl', 'sing', 'stage'],
#  ['woman', 'ride', 'hors'],
#  ['girl', 'play', 'guitar'],
#  ['woman', 'brush', 'shrimp'],
#  ['man', 'danc', 'ceil'],
#  ['woman', 'thinli', 'slice', 'onion', 'larg', 'knife'],
#  ['man', 'play', 'keyboard'],
#  ['man', 'play', 'guitar'],
#  ['woman', 'peel', 'potato'],
#  ['woman', 'handl', 'frog'],
#  ['man', 'play', 'flute'],
#  ['man', 'play', 'guitar'],
#  ['man', 'play', 'piano'],
#  ['man', 'play', 'guitar'],
#  ['man', 'play', 'flute'],
#  ['man', 'play', 'flute'],
#  ['two', 'woman', 'couch'],
#  ['someon', 'slice', 'cucumb'],
#  ['kitten', 'play', 'blue', 'rope', 'toy'],
#  ['dog', 'bark', 'toy'],
#  ['person', 'fold', 'tortilla'],
#  ['cat', 'drink', 'milk'],
#  ['person', 'drive', 'car'],
#  ['turtl', 'walk'],
#  ['cow', 'eat', 'grass'],
#  ['woman', 'chop', 'broccoli'],
#  ['man', 'cri'],
#  ['man', 'play', 'guitar'],
#  ['man', 'cut', 'onion'],
#  ['man', 'slice', 'potato'],
#  ['woman', 'tap', 'finger', 'tabl'],
#  ['someon', 'boil', 'okra', 'pot'],
#  ['man', 'smoke'],
#  ['man', 'play', 'drum'],
#  ['man', 'dive', 'pool'],
#  ['woman', 'cut', 'leak'],
#  ['littl', 'boy', 'play', 'guitar'],
#  ['woman', 'danc'],
#  ['woman', 'talk'],
#  ['girl', 'put', 'gel', 'hair'],
#  ['kid', 'play', 'guitar'],
#  ['group', 'peopl', 'march', 'place'],
#  ['woman', 'shoot', 'machin', 'gun'],
#  ['man', 'play', 'piano'],
#  ['woman', 'slice', 'onion'],
#  ['man', 'slice', 'cucumb'],
#  ['girl', 'eat', 'cupcak'],
#  ['woman', 'cut', 'onion'],
#  ['man', 'play', 'guitar'],
#  ['man', 'play', 'guitar'],
#  ['two', 'littl', 'girl', 'talk', 'telephon'],
#  ['man', 'chop', 'log', 'axe'],
#  ['person', 'cut', 'capsicum', 'piec'],
#  ['man', 'talk', 'woman'],
#  ['man', 'walk'],
#  ['someon', 'pour', 'oil', 'skillet'],
#  ['small', 'kitten', 'play', 'ball'],
#  ['man', 'play', 'guitar'],
#  ['girl', 'play', 'violin'],
#  ['man', 'play', 'two', 'piano'],
#  ['man', 'exercis'],
#  ['person', 'slice', 'scallop'],
#  ['man', 'woman', 'ride', 'bicycl'],
#  ['two', 'men', 'fight', 'cow', 'pastur'],
#  ['woman', 'ad', 'oil', 'pan'],
#  ['girl', 'make', 'bed'],
#  ['cat', 'play', 'watermelon'],
#  ['girl', 'jump', 'car'],
#  ['man', 'pray'],
#  ['car', 'park'],
#  ['man', 'run'],
#  ['man', 'sing'],
#  ['man', 'carri', 'anoth', 'man', 'shoulder'],
#  ['woman', 'peel', 'potato'],
#  ['woman', 'cut', 'tomato'],
#  ['someon', 'peel', 'potato'],
#  ['woman', 'peel', 'potato'],
#  ['two', 'robot', 'kiss'],
#  ['two', 'boy', 'couch', 'play', 'video', 'game'],
#  ['woman', 'squeez', 'lemon'],
#  ['woman', 'slice', 'onion'],
#  ['woman', 'slice', 'carrot'],
#  ['girl', 'style', 'hair'],
#  ['man', 'walk', 'stair'],
#  ['two', 'peopl', 'ride', 'motorcycl'],
#  ['man', 'play', 'guitar'],
#  ['man', 'play', 'guitar', 'sing'],
#  ['man', 'walk', 'rain'],
#  ['kangaroo', 'eat'],
#  ['man', 'fish'],
#  ['woman', 'swim'],
#  ['woman', 'eat'],
#  ['boy', 'girl', 'danc', 'rain'],
#  ['man', 'drive', 'car'],
#  ['woman', 'grate', 'onion'],
#  ['two', 'rooster', 'fight'],
#  ['man', 'ride', 'hors'],
#  ['man', 'ride', 'hors'],
#  ['man', 'shoot', 'gun'],
#  ['woman', 'cut', 'onion'],
#  ['woman', 'slice', 'herb'],
#  ['boy', 'play', 'piano'],
#  ['babi', 'eleph', 'eat'],
#  ['woman', 'crack', 'egg', 'bowl'],
#  ['person', 'play', 'keyboard'],
#  ['boy', 'whack', 'man', 'sword'],
#  ['person', 'slice', 'carrot', 'piec'],
#  ['man', 'slice', 'bunch', 'water', 'bottl', 'knife'],
#  ['man', 'write', 'book'],
#  ['woman', 'slice', 'garlic'],
#  ['person', 'make', 'bed'],
#  ['man', 'play', 'keyboard'],
#  ['man', 'play', 'violin'],
#  ['woman', 'smoke'],
#  ['man', 'eras', 'man', 'board'],
#  ['man', 'ride', 'motorcycl'],
#  ['man', 'ride', 'motorcycl', 'highway'],
#  ['woman', 'slice', 'meat'],
#  ['woman', 'cut', 'broccoli'],
#  ['man', 'play', 'piano'],
#  ['someon', 'slice', 'tomato'],
#  ['woman', 'danc', 'cage'],
#  ['woman', 'swim'],
#  ['man', 'run'],
#  ['man', 'play', 'guitar'],
#  ['cat', 'stare', 'camera'],
#  ['babi', 'laugh', 'crawl'],
#  ['woman', 'shoot', 'gun'],
#  ['woman', 'danc', 'rain'],
#  ['woman', 'danc'],
#  ['kid', 'play', 'instrument'],
#  ['someon', 'slice', 'bottl', 'sword'],
#  ['woman', 'cut', 'appl'],
#  ['man', 'peel', 'appl'],
#  ['man', 'play', 'guitar'],
#  ['anim', 'walk', 'ground'],
#  ['littl', 'girl', 'play', 'grand', 'piano', 'stage'],
#  ['group', 'peopl', 'danc'],
#  ['man', 'play', 'guitar'],
#  ['cat', 'swing', 'ceil', 'fan'],
#  ['woman', 'play', 'flute'],
#  ['woman', 'dice', 'onion'],
#  ['monkey', 'brush', 'bull', 'dog'],
#  ['woman', 'slice', 'onion'],
#  ['man', 'play', 'piano'],
#  ['woman', 'wash', 'hand'],
#  ['woman', 'fire', 'shotgun'],
#  ['man', 'eat', 'bowl', 'cereal'],
#  ['woman', 'bath', 'bathtub'],
#  ['motorcyclist', 'crash', 'motorcycl'],
#  ['man', 'dangl', 'mous', 'near', 'snake'],
#  ['man', 'woman', 'walk', 'wood'],
#  ['person', 'pour', 'rice', 'pud', 'bowl'],
#  ['man', 'stare', 'window'],
#  ['woman', 'fire', 'rifl'],
#  ['man', 'eat', 'banana'],
#  ['men', 'perform', 'stage'],
#  ['cartoon', 'woman', 'dive', 'pool'],
#  ['ladi', 'put', 'babi', 'int', 'trashcan'],
#  ['someon', 'fri', 'meat'],
#  ['man', 'rapidli', 'chop', 'mushroom', 'use', 'knife'],
#  ['woman', 'ad', 'ingredi', 'bowl'],
#  ['skateboard', 'trick', 'halfpip'],
#  ['man', 'speak', 'stage'],
#  ['man', 'play', 'guitar'],
#  ['man', 'play', 'keyboard'],
#  ['person', 'cut', 'potato'],
#  ['man', 'danc', 'ceil', 'room'],
#  ['two', 'men', 'danc'],
#  ['someon', 'season', 'egg'],
#  ['man', 'swing', 'rope'],
#  ['man', 'cut', 'tomato'],
#  ['woman', 'boil', 'shrimp'],
#  ['man', 'cut', 'potato'],
#  ['man', 'danc', 'road'],
#  ['deer', 'jump', 'fenc'],
#  ['girl', 'danc', 'rain'],
#  ['woman', 'write', 'letter'],
#  ['gorilla', 'play', 'drum'],
#  ['woman', 'ride', 'hors'],
#  ['boy', 'cut', 'grass', 'curb', 'scissor'],
#  ['man', 'glass', 'talk'],
#  ['woman', 'cut', 'flower'],
#  ['person', 'walk', 'stone', 'path'],
#  ['man', 'play', 'keyboard', 'nose'],
#  ['man', 'play', 'guitar'],
#  ['anim', 'eat'],
#  ['man', 'lift', 'weight'],
#  ['man', 'run', 'bu'],
#  ['man', 'climb', 'rope'],
#  ['cat', 'play', 'piano'],
#  ['woman', 'danc', 'rain'],
#  ['men', 'run', 'race'],
#  ['man', 'cut', 'tomato', 'piec'],
#  ['man', 'play', 'flute'],
#  ['woman', 'cut', 'potato'],
#  ['chicken', 'peck', 'dead', 'mous'],
#  ['woman', 'thinli', 'slice', 'cucumb'],
#  ['person', 'slice', 'bread', 'piec'],
#  ['woman', 'cut', 'squash'],
#  ['woman', 'ad', 'oil', 'fish'],
#  ['woman', 'grate', 'carrot'],
#  ['someon', 'clean', 'anim'],
#  ['man', 'talk', 'phone'],
#  ['woman', 'smoke'],
#  ['man', 'lay', 'shoot', 'gun'],
#  ['man', 'put', 'abul'],
#  ['man', 'dive', 'swim', 'pool'],
#  ['man', 'fire', 'shot', 'gun'],
#  ['man', 'play', 'guitar'],
#  ['man', 'peel', 'potato'],
#  ['woman', 'ride', 'hors'],
#  ['airplan', 'move', 'along', 'runway'],
#  ['woman', 'slip', 'watertub'],
#  ['man', 'mow', 'lawn'],
#  ['woman', 'peel', 'potato'],
#  ['man', 'play', 'piano'],
#  ['woman', 'ballet'],
#  ['woman', 'cut', 'onion'],
#  ['woman', 'stir', 'rice', 'pot'],
#  ['woman', 'put', 'slab', 'meat', 'pan'],
#  ['boy', 'play', 'trumpet'],
#  ['person', 'ride', 'hors'],
#  ['woman', 'slice', 'onion'],
#  ['man', 'slice', 'veget'],
#  ['cat', 'play'],
#  ['man', 'ride', 'bicycl'],
#  ['band', 'perform', 'stage'],
#  ['woman', 'slice', 'fish', 'cake'],
#  ['man', 'eat', 'bread'],
#  ['woman', 'cook', 'shrimp'],
#  ['woman', 'danc'],
#  ['woman', 'toss', 'cat', 'air', 'cat', 'hang', 'rod', 'ceil'],
#  ['big', 'turtl', 'walk'],
#  ['man', 'burn', 'flag'],
#  ['man', 'push', 'van'],
#  ['man', 'eat', 'wood'],
#  ['dog', 'speak', 'camera'],
#  ['man', 'put', 'two', 'paper', 'towel', 'paper', 'plate'],
#  ['man', 'woman', 'walk'],
#  ['man', 'cut', 'rope', 'sword'],
#  ['man', 'sing', 'play', 'guitar'],
#  ['man', 'cut', 'paper'],
#  ['man', 'danc'],
#  ['two', 'boy', 'talk', 'phone'],
#  ['man', 'play', 'guitar'],
#  ['woman', 'slice', 'onion'],
#  ['woman', 'ride', 'hors'],
#  ['man', 'play', 'soccer'],
#  ['woman', 'peel', 'orang'],
#  ['someon', 'crack', 'egg', 'open'],
#  ['man', 'cut', 'snake', 'cook'],
#  ['woman', 'scrape', 'carrot'],
#  ['man', 'woman', 'bollywood', 'danc'],
#  ['woman', 'cut', 'flower'],
#  ['man', 'danc', 'diner'],
#  ['american', 'flag', 'wave'],
#  ['lion', 'walk', 'enclos', 'area'],
#  ['woman', 'slice', 'lemon'],
#  ['woman', 'play', 'flute'],
#  ['dog', 'bark', 'toy'],
#  ['woman', 'ad', 'egg', 'stir'],
#  ['woman', 'cover', 'piec', 'meat', 'flour'],
#  ['white',
#   'cat',
#   'perch',
#   'small',
#   'wooden',
#   'cabinet',
#   'look',
#   'outsid',
#   'window'],
#  ['man', 'floor', 'exercis'],
#  ['man', 'slice', 'potato'],
#  ['someon', 'play', 'piano'],
#  ['woman', 'put', 'makeup', 'man'],
#  ['woman', 'dropp', 'eggplant', 'pan'],
#  ['man', 'play', 'trumpet'],
#  ['woman', 'slice', 'lemon'],
#  ['tiger', 'tri', 'climb', 'wall'],
#  ['man', 'prepar', 'hang', 'rope'],
#  ['woman', 'danc', 'stage'],
#  ['girl', 'ride', 'hors'],
#  ['person', 'fri'],
#  ['man', 'shoot', 'pistol'],
#  ['woman', 'swing', 'arm'],
#  ['man', 'walk', 'outsid'],
#  ['man', 'dri', 'hand'],
#  ['soccer',
#   'player',
#   'kick',
#   'soccer',
#   'ball',
#   'goal',
#   'long',
#   'way',
#   'field'],
#  ['girl', 'play', 'piano'],
#  ['man', 'draw', 'figur'],
#  ['monkey', 'hang', 'tree'],
#  ['child', 'jump', 'trampolin'],
#  ['woman', 'knife', 'slice', 'pepper'],
#  ['man', 'ad', 'oil', 'car'],
#  ['man', 'slice', 'carrot', 'machin'],
#  ['boy', 'play', 'keyboard'],
#  ['cat', 'play', 'antenna'],
#  ['woman', 'slice', 'pumpkin'],
#  ['peopl', 'threw', 'dummi', 'cliff', 'edg'],
#  ['gun', 'fire'],
#  ['woman', 'cut', 'plastic', 'sheet'],
#  ['woman', 'cut', 'pineappl'],
#  ['woman', 'ad', 'spice', 'meat'],
#  ['person', 'ad', 'oil', 'pan'],
#  ['cook', 'season', 'dough'],
#  ['boy', 'run', 'beach'],
#  ['babi', 'monkey', 'scratch'],
#  ['boy', 'ride', 'bike', 'gate'],
#  ['man', 'card', 'trick'],
#  ['man', 'play', 'piano'],
#  ['man', 'mow', 'grass'],
#  ['person', 'mix', 'water', 'flour'],
#  ['two', 'dog', 'pen'],
#  ['man', 'ride', 'one', 'wheel', 'motorcycl'],
#  ['cat', 'open', 'drawer', 'climb', 'insid'],
#  ['man', 'open', 'box', 'use', 'knife'],
#  ['man', 'kick', 'oot', 'water'],
#  ['man', 'eat'],
#  ['puppi', 'repeatedli', 'roll', 'side', 'side', 'back'],
#  ['young', 'boy', 'sing', 'play', 'guitar'],
#  ['woman', 'peel', 'lemon'],
#  ['man', 'play', 'trumpet'],
#  ['dog', 'look', 'around'],
#  ['woman', 'slice', 'onion'],
#  ['man', 'drill', 'hole', 'wood'],
#  ['someon', 'cut', 'circl', 'pink', 'sheet', 'paper'],
#  ['man', 'play', 'flute'],
#  ['man', 'place', 'meat', 'bag'],
#  ['girl', 'eat', 'cupcak'],
#  ['rabbit', 'snif', 'paw', 'stuf', 'rabbit'],
#  ['man', 'butter', 'bread'],
#  ['woman', 'squeez', 'cucumb', 'slice'],
#  ['man', 'take', 'insid', 'green', 'pepper'],
#  ['man',
#   'take',
#   'piec',
#   'pepperoni',
#   'pizza',
#   'pizza',
#   'box',
#   'put',
#   'lid',
#   'close',
#   'box'],
#  ['man', 'ad', 'veget', 'broth', 'pot'],
#  ['man', 'ran', 'jump', 'wall'],
#  ['man', 'season', 'sausag'],
#  ['clown', 'sing', 'peopl', 'danc'],
#  ['woman', 'feed', 'aardvark'],
#  ['person', 'rins', 'steak', 'water'],
#  ['boy', 'rode', 'bike', 'top', 'metal', 'fenc'],
#  ['man', 'throw', 'knife', 'tree'],
#  ['girl', 'walk', 'stage'],
#  ['woman', 'weight', 'exercis'],
#  ['man', 'peel', 'potato'],
#  ['larg',
#   'bird',
#   'stand',
#   'tabl',
#   'pick',
#   'plastic',
#   'glass',
#   'contain',
#   'liquid',
#   'place',
#   'bowl',
#   'someth'],
#  ['woman', 'rain'],
#  ['woman', 'hit', 'man'],
#  ['woman', 'ride', 'eleph'],
#  ['man', 'lift', 'weight'],
#  ['person', 'ride', 'jetski', 'wave'],
#  ['woman', 'wear', 'headphon'],
#  ['kitten', 'eat', 'food', 'plate'],
#  ['woman', 'read', 'lifestyl', 'magazin'],
#  ['man', 'pour', 'chili', 'bowl'],
#  ['bird', 'ate', 'food', 'tree', 'bowl'],
#  ['group', 'girl', 'exit', 'taxi'],
#  ['woman', 'season', 'piec', 'meat'],
#  ['man', 'chop', 'coriand', 'leaf'],
#  ['man', 'take', 'slice', 'pizza'],
#  ['man', 'place', 'meat', 'insid', 'plastic', 'bag'],
#  ['rabbi', 'talk'],
#  ['man', 'ride', 'hors'],
#  ['man', 'play', 'guitar'],
#  ['man', 'slice', 'bun'],
#  ['man', 'drive', 'car'],
#  ['dog', 'paw', 'fli', 'carpet'],
#  ['dog', 'bark'],
#  ['monkey', 'walk', 'bed'],
#  ['woman', 'cook', 'broccoli'],
#  ['man', 'fri', 'tortilla'],
#  ['woman', 'serv', 'volleybal', 'net'],
#  ['man', 'slice', 'cucumb', 'knife'],
#  ['man', 'play', 'electron', 'keyboard'],
#  ['man', 'play', 'violin'],
#  ['man', 'sever', 'toe', 'empti', 'leather', 'boot', 'use', 'sword'],
#  ['person', 'remov', 'scale', 'fish'],
#  ['peopl', 'walk', 'garden'],
#  ['young', 'child', 'ride', 'hors'],
#  ['person', 'cut', 'garlic', 'piec', 'knife'],
#  ['man', 'fold', 'piec', 'paper'],
#  ['man', 'push', 'water'],
#  ['boy', 'upset', 'play', 'video', 'game'],
#  ['man', 'make', 'call', 'cell', 'phone'],
#  ['man', 'speak', 'phone'],
#  ['woman', 'appli', 'cosmet', 'face'],
#  ['man', 'lift', 'barbel'],
#  ['woman', 'feed', 'anim', 'hand'],
#  ['sever', 'ferret', 'climb', 'cage'],
#  ['young', 'woman', 'play', 'flute'],
#  ['woman', 'shoot', 'shotgun'],
#  ['person', 'ad', 'chili', 'powder', 'chili', 'bean'],
#  ['woman', 'rapidli', 'fire', 'handgun'],
#  ['person', 'slice', 'onion'],
#  ['dog', 'open', 'fridg'],
#  ['woman', 'hold', 'danc', 'babi'],
#  ['woman', 'joker', 'make', 'man'],
#  ['ladi', 'ad', 'chees', 'sauc'],
#  ['man', 'give', 'lectur', 'podium'],
#  ['cat', 'shimmi', 'bed'],
#  ['woman', 'chop', 'garlic'],
#  ['man', 'cut', 'grass'],
#  ['man', 'cut', 'grass'],
#  ['boy', 'run', 'away', 'fish', 'line'],
#  ['man', 'play', 'haki', 'sak', 'offic'],
#  ['man', 'carri', 'anoth', 'man', 'back'],
#  ['meat', 'drop', 'pan'],
#  ['woman', 'cut', 'scallion'],
#  ['man', 'slam', 'dunk', 'ball'],
#  ['machin', 'sharpen', 'pencil'],
#  ['woman', 'brush', 'foot'],
#  ['man', 'clean', 'window'],
#  ['person', 'stir', 'rice'],
#  ['man', 'put', 'knife', 'vice'],
#  ['boy', 'play', 'violin', 'stage'],
#  ['woman', 'cut', 'pink', 'loaf', 'knife'],
#  ['man', 'ad', 'pork', 'chop', 'pan'],
#  ['men', 'fight'],
#  ['man', 'catch', 'ball'],
#  ['girl', 'read', 'newspap'],
#  ['slow', 'lori', 'bite', 'person', 'finger'],
#  ['man', 'walk', 'along', 'path', 'wilder'],
#  ['man', 'play', 'guitar'],
#  ['men', 'skate', 'road'],
#  ['man', 'pour', 'liquid', 'pan'],
#  ['boy', 'play', 'piano', 'sing'],
#  ['cat', 'ferret', 'play'],
#  ['monkey', 'walk', 'water'],
#  ['woman', 'put', 'makeup'],
#  ['dog', 'drive', 'car'],
#  ['man', 'sang', 'stage', 'microphon'],
#  ['car', 'back', 'space'],
#  ['man', 'hold', 'frog'],
#  ['man', 'travel', 'boat'],
#  ['man', 'rode', 'motorcycl', 'highway'],
#  ['man', 'dice', 'onion'],
#  ['man', 'perform', 'stage'],
#  ['woman', 'siti'],
#  ['man', 'remov', 'coupl', 'toaster', 'scrambl', 'plastic', 'packet'],
#  ['woman', 'danc', 'fire'],
#  ['man', 'medit'],
#  ['boy', 'cut', 'paper'],
#  ['man', 'talk', 'telephon'],
#  ['man', 'play', 'guitar', 'sing'],
#  ['soccer', 'player', 'kick', 'ball', 'side', 'side', 'leg'],
#  ['anim', 'walk'],
#  ['someon', 'scratch', 'anim', 'belli'],
#  ['man', 'lift', 'heavi', 'weight'],
#  ['boy', 'play', 'toy'],
#  ['man', 'dive', 'cliff'],
#  ['man', 'come', 'water'],
#  ['man', 'woman', 'danc'],
#  ['man', 'sweep', 'floor', 'hous', 'use', 'long', 'broom'],
#  ['group', 'coupl', 'danc'],
#  ['man', 'scale', 'fish'],
#  ['man', 'set', 'camera', 'take', 'sunset', 'pictur', 'beach'],
#  ['someon', 'hold', 'pet', 'babi', 'tiger'],
#  ['man', 'play', 'guitar'],
#  ['man', 'pushup', 'wall'],
#  ['woman', 'cut', 'veget'],
#  ['person', 'break', 'egg', 'small', 'bowl'],
#  ['man', 'play', 'keyboard'],
#  ['dog', 'run', 'around', 'yard'],
#  ['child', 'walk', 'street', 'jeep', 'pull'],
#  ['man', 'ad', 'oil', 'pot'],
#  ['girl', 'danc', 'front', 'bonfir'],
#  ['man', 'chop', 'butter', 'contain'],
#  ['girl', 'drag', 'downhil', 'dog'],
#  ['man', 'took', 'sunglass', 'talk'],
#  ['two', 'men', 'funni', 'skit', 'boxer', 'front', 'crowd', 'peopl'],
#  ['girl', 'tide', 'bed'],
#  ['someoen', 'cook', 'onion'],
#  ['man', 'use', 'sledghamm', 'break', 'concret', 'block', 'man'],
#  ['ladi', 'put', 'dri', 'noodl', 'hot', 'water', 'cook'],
#  ['girl', 'danc', 'stage'],
#  ['panda', 'bear', 'lay'],
#  ['two', 'kid', 'play', 'swim', 'pool', 'green', 'color', 'crocodil', 'float'],
#  ['coupl', 'policewoman', 'sing', 'karaok'],
#  ['man', 'put', 'broccoli', 'water'],
#  ['doctor', 'help', 'patient'],
#  ['grate', 'onion', 'water'],
#  ['babi', 'talk'],
#  ['woman', 'boil', 'egg'],
#  ['woman', 'put', 'ingredi', 'whisk', 'egg'],
#  ['woman', 'slice', 'mango'],
#  ['girl', 'slice', 'butter', 'two', 'piec'],
#  ['man', 'play', 'guitar'],
#  ['man', 'open', 'packag', 'contain', 'headphon'],
#  ['girl', 'play', 'guitar'],
#  ['littl', 'girl', 'play', 'violin', 'beach'],
#  ['monkey', 'karat', 'kick', 'someon', 'glove', 'hand'],
#  ['femal', 'appli', 'someth', 'hair', 'hand'],
#  ['man', 'karat', 'kick', 'anoth', 'man', 'wear', 'protect', 'box', 'glove'],
#  ['man', 'play', 'wooden', 'flute'],
#  ['young', 'woman', 'play', 'guitar'],
#  ['men', 'play', 'soccer'],
#  ['woman', 'run', 'beach'],
#  ['man', 'strain', 'pasta'],
#  ['panda', 'play', 'swing'],
#  ...]

# %%
documents = []
for idx, sent in enumerate(total_sents_unk):
    documents.append(TaggedDocument(sent, [idx]))

# %%
model = Doc2Vec(documents, vector_size=25, window=6, min_count=1, workers=1, epochs=30, alpha=0.1, min_alpha=0.001, hs=1)

# %%
model.random.seed(42)
train_data['sentence1'] = train_data['sentence1'].apply(lambda x: model.infer_vector(x))
train_data['sentence2'] = train_data['sentence2'].apply(lambda x: model.infer_vector(x))

# %%
y_pred = train_data.apply(lambda x: ((1 - spatial.distance.cosine(x['sentence1'], x['sentence2']))+1)*2.5, axis=1)
y_train = train_data['score']
corr = pearson_corr(y_train, y_pred)
print("Pearson correlation coefficient: {:.2f}".format(corr))
# Out:
# Pearson correlation coefficient: 0.50

# %%
val_data['sentence1'] = val_data['sentence1'].apply(lambda x: model.infer_vector(x))
val_data['sentence2'] = val_data['sentence2'].apply(lambda x: model.infer_vector(x))

# %%
y_pred = val_data.apply(lambda x: ((1 - spatial.distance.cosine(x['sentence1'], x['sentence2']))+1)*2.5, axis=1)
y_train = val_data['score']
corr = pearson_corr(y_train, y_pred)
print("Pearson correlation coefficient: {:.2f}".format(corr))
# Out:
# Pearson correlation coefficient: 0.61

# %%
test_data['sentence1'] = test_data['sentence1'].apply(lambda x: model.infer_vector(x))
test_data['sentence2'] = test_data['sentence2'].apply(lambda x: model.infer_vector(x))

# %%
y_pred = test_data.apply(lambda x: ((1 - spatial.distance.cosine(x['sentence1'], x['sentence2']))+1)*2.5, axis=1)
y_train = test_data['score']
corr = pearson_corr(y_train, y_pred)
print("Pearson correlation coefficient: {:.2f}".format(corr))
# Out:
# Pearson correlation coefficient: 0.54

# %% [markdown]
# ### BiLSTM Model

# %%
train_embeddings1 = torch.Tensor(list(train_data['sentence1']))
train_embeddings2 = torch.Tensor(list(train_data['sentence2']))
train_score = torch.Tensor(list(train_data['score']))

val_embeddings1 = torch.Tensor(list(val_data['sentence1']))
val_embeddings2 = torch.Tensor(list(val_data['sentence2']))
val_score = torch.Tensor(list(val_data['score']))

test_embeddings1 = torch.Tensor(list(test_data['sentence1']))
test_embeddings2 = torch.Tensor(list(test_data['sentence2']))
test_score = torch.Tensor(list(test_data['score']))

# %%
input_dim = 25
hidden_dim = 25
lr = 0.001
num_epochs = 10
batch_size = 10

# %%
class BiLSTMRegression(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers):
        super().__init__()
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.bilstm = nn.LSTM(input_dim, hidden_dim, num_layers=num_layers, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_dim*2, 1)

    def forward(self, x1, x2):
        x = torch.cat((x1, x2), dim=1)
        x = x.view(len(x), 1, -1)
        h0 = torch.zeros(self.num_layers*2, len(x), self.hidden_dim).to(x.device)
        c0 = torch.zeros(self.num_layers*2, len(x), self.hidden_dim).to(x.device)
        out, _ = self.bilstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# %%
model = BiLSTMRegression(input_dim*2, hidden_dim, num_layers=2)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion = nn.MSELoss()

class SentenceSimilarityDataset(data.Dataset):
    def __init__(self, embeddings1, embeddings2, scores):
        self.embeddings1 = embeddings1
        self.embeddings2 = embeddings2
        self.scores = scores

    def __len__(self):
        return len(self.embeddings1)

    def __getitem__(self, index):
        return self.embeddings1[index], self.embeddings2[index], self.scores[index]
    
train_dataset = SentenceSimilarityDataset(train_embeddings1, train_embeddings2, train_score)
val_dataset = SentenceSimilarityDataset(val_embeddings1, val_embeddings2, val_score)

train_dataloader = data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    for batch in train_dataloader:
        optimizer.zero_grad()
        embeddings1_batch, embeddings2_batch, scores_batch = batch
        output = model(embeddings1_batch, embeddings2_batch)
        loss = criterion(output.squeeze(), scores_batch)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * len(embeddings1_batch)
    train_loss /= len(train_embeddings1)

    val_loss = 0
    with torch.no_grad():
        for batch in val_dataloader:
            embeddings1_batch, embeddings2_batch, scores_batch = batch
            val_output = model(embeddings1_batch, embeddings2_batch)
            val_loss += criterion(val_output.squeeze(), scores_batch).item() * len(embeddings1_batch)
    val_loss /= len(val_embeddings1)

    print(f"Epoch = {epoch}\tTraining Loss = {train_loss}\tValidation Loss = {val_loss}")
# Out:
# Epoch = 0	Training Loss = 2.7887633158489193	Validation Loss = 2.1403739698727926
# Epoch = 1	Training Loss = 1.8022376451104138	Validation Loss = 2.027794901529948
# Epoch = 2	Training Loss = 1.5637056298060177	Validation Loss = 1.9546881838639578
# Epoch = 3	Training Loss = 1.3493448697311772	Validation Loss = 1.962295016447703
# Epoch = 4	Training Loss = 1.176512693001677	Validation Loss = 2.11602485537529
# Epoch = 5	Training Loss = 1.0422908059538583	Validation Loss = 2.134304936329524
# Epoch = 6	Training Loss = 0.9178078691271787	Validation Loss = 2.202509037653605
# Epoch = 7	Training Loss = 0.8183255956875467	Validation Loss = 2.349531631072362
# Epoch = 8	Training Loss = 0.729214679673353	Validation Loss = 2.4347394144535066
# Epoch = 9	Training Loss = 0.654054634225101	Validation Loss = 2.5370150164763134

# %%
model.eval()
output = model(train_embeddings1, train_embeddings2)
y_pred = output.squeeze().tolist()
y_train = train_score
corr = pearson_corr(y_train, y_pred)
print("Pearson correlation coefficient: {:.2f}".format(corr))
# Out:
# Pearson correlation coefficient: 0.87

# %%
model.eval()
output = model(val_embeddings1, val_embeddings2)
y_pred = output.squeeze().tolist()
y_val = val_score
corr = pearson_corr(y_val, y_pred)
print("Pearson correlation coefficient: {:.2f}".format(corr))
# Out:
# Pearson correlation coefficient: 0.38

# %%
model.eval()
output = model(test_embeddings1, test_embeddings2)
y_pred = output.squeeze().tolist()
y_test = test_score
corr = pearson_corr(y_test, y_pred)
print("Pearson correlation coefficient: {:.2f}".format(corr))
# Out:
# Pearson correlation coefficient: 0.34
